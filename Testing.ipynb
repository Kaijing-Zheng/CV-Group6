# %%
import os
import numpy as np
import keras
from keras import layers
import tensorflow as tf
from tensorflow import data as tf_data
import matplotlib.pyplot as plt

# %%
pip install pillow

# %%
#Edge detection and remove border of each image assuming equal size
from PIL import Image, ImageFilter

test_img = Image.open("/Users/dli3/Desktop/Duke Materials/DAML/CV-Group6/asl_alphabet_train/A/A1.jpg")
test_img = test_img.convert("L")
test_img = test_img.filter(ImageFilter.FIND_EDGES)
crop_box = (10,10,180,180)
test_img = test_img.crop(crop_box)
test_img
